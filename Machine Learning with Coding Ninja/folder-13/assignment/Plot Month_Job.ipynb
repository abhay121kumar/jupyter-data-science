# %%
import csv
import matplotlib.pyplot as plt
import collections
with open('amazonjobsdataset.csv', encoding ='UTF-8') as file_obj:
    file_data = csv.DictReader(file_obj, skipinitialspace=True)

    dct = {}
    for row in file_data:
        date = row['Posting_date'].split()
        key = date[0]
        if key in dct:
            dct[key] += 1
        else:
            dct[key] = 1
#     print(key)        
    ord_dct = collections.OrderedDict(sorted(dct.items()))                                  
    plt.bar(list(ord_dct.keys()),list(ord_dct.values()))
    plt.xlabel("Month")
    plt.ylabel("Jobs")
    plt.title('Month vs Job_Openings')
    plt.xticks(rotation = 40)
    plt.show()
    
    for i in ord_dct.keys():
        print(i,end=" ")
        print(ord_dct[i])
# Out:
# July

# %%
import csv
import matplotlib.pyplot as plt
import collections

# %%
with open("amazonjobsdataset.csv") as file_obj:
    data = csv.DictReader(file_obj, skipinitialspace=True)
    dct = {}
    for i in data:
        job = i['Posting_date'].split()
        key = job[0]
        if key in dct:
            dct[key]+=1
        else:
            dct[key] = 1
    dct_keys = list(dct.keys())
    dct_values = list(dct.values())
    plt.plot(dct_keys, dct_values)
    plt.show()

# %%
with open("amazonjobsdataset.csv") as file_obj:
    data = csv.DictReader(file_obj, skipinitialspace=True)
    dct = {}
    for i in data:
        job = i['Posting_date'].split()
        key = job[0]
        if key in dct:
            dct[key]+=1
        else:
            dct[key] = 1
    dct_keys = list(dct.keys())
    dct_values = list(dct.values())
    plt.bar(dct_keys, dct_values)
    plt.xlabel("Month")
    plt.ylabel("Jobs")
    plt.title('Month vs Job_Openings')
    plt.xticks(rotation = 40)
    plt.show()

# %%
with open("amazonjobsdataset.csv") as file_obj:
    data = csv.DictReader(file_obj, skipinitialspace=True)
    dct = {}
    for i in data:
        job = i['Posting_date'].split()
        key = job[0]
        if key in dct:
            dct[key]+=1
        else:
            dct[key] = 1
    ord_dct = collections.OrderedDict(sorted(dct.items())) 
    dct_keys = list(ord_dct.keys())
    dct_values = list(ord_dct.values())
    plt.bar(dct_keys, dct_values)
    plt.xlabel("Month")
    plt.ylabel("Jobs")
    plt.title('Month vs Job_Openings')
    plt.xticks(rotation = 40)
    plt.show()
