# %%
import matplotlib.pyplot as plt
employees = [61,71,79,91,93,89,90,94,99,128,118,114,124,131]
year = [2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018]
revenue = [39.79,44.28,51.12,60.42,58.44,62.48,69.94,73.72,77.85,86.83,93.58,85.32,89.95,110.36]
s
plt.scatter(year, revenue, s=employees, c="r")

plt.xlabel("year")
plt.ylabel("revenue")
plt.title("Microsoft Bubble Graph")

plt.grid()

# plt.legend()

plt.text(2008+0.2, 60+0.2, "dc")
plt.text(2015+0.2, 93.58+0.2, "dc")

print("year-2008", "revenue-60", "employee-91")
print("year-2015", "revenue-93", "employee-118")
# Out:
# year-2008 revenue-60 employee-91
# year-2015 revenue-93 employee-118

# %%
import matplotlib.pyplot as plt
employees = [61,71,79,91,93,89,90,94,99,128,118,114,124,131]
year = [2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018]
revenue = [39.79,44.28,51.12,60.42,58.44,62.48,69.94,73.72,77.85,86.83,93.58,85.32,89.95,110.36]

plt.scatter(year,revenue,s=employees,c='r')
plt.grid()
plt.show()


print('2008','60.42','91')
print('2015','93.58','118')
# Out:
# 2008 60.42 91
# 2015 93.58 118

# %%
import matplotlib.pyplot as plt
import numpy as np

x1 = [0,1,2,3,4,5,6,7,9,10]
y1 = [1,2,5,10,17,26,37,50,82,101]

np_x1 = np.array(x1)
np_y1 = np.array(y1)
np_x2 = np.arange(0,40,2)
np_y2 = np_x2

plt.plot(np_x1, np_y1, color = "blue", label = "x1")
plt.plot(np_x2, np_y2, color = "pink", label = "y1")

plt.legend()
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
# Out:
# Text(0, 0.5, 'Y-axis')

# %%
# Out:
# year-2008 revenue-60 employee-91
# year-2015 revenue-93 employee-118
