# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3]
y = [2,4,6]

plt.scatter(x, y)

# %%
plt.show()

# %%
it takes random colour

# %%
x = [1,2,3]
y = [2,4,6]

plt.scatter(x, y)

# %%
x = [1,2,3]
y = [2,4,6]

plt.plot(x, y)

# %%
x = [1,2,3]
y = [2,4,6]

plt.scatter(x, y)
plt.plot(x, y)

# %%
x = [1,2,3]
y = [2,4,6]

x1 = [3,4,5]
y1 = [2,4,6]

plt.plot(x1, y1)
plt.plot(x, y)

# %% [markdown]
# # "(1st char of string)(second char onwards)"
# ## 1st char -> decide which colour you want to use
# ## 2nd char onwards -> will decide which marker you want to use
# like
# circle
# triangle
# line
# dash
# etc.

# %%
x = [1,2,3]
y = [2,4,6]

x1 = [3,4,5]
y1 = [2,4,6]

plt.plot(x1, y1, "r")
plt.plot(x, y)

# %% [markdown]
# # why we are doing like that because we want to see our graph
# # in different form

# %%
x = [1,2,3]
y = [2,4,6]

x1 = [3,4,5]
y1 = [2,4,6]

plt.plot(x1, y1, "ro")
plt.plot(x, y)

# %%
x = [1,2,3]
y = [2,4,6]

x1 = [3,4,5]
y1 = [2,4,6]

plt.plot(x1, y1, "r-")
plt.plot(x, y)

# %%
x = [1,2,3]
y = [2,4,6]

x1 = [3,4,5]
y1 = [2,4,6]

plt.plot(x1, y1, "r--")
plt.plot(x, y)

# %%
x = [1,2,3]
y = [2,4,6]

x1 = [3,4,5]
y1 = [2,4,6]

plt.plot(x1, y1, "r+")
plt.plot(x, y)

# %%
x = [1,2,3]
y = [2,4,6]

x1 = [3,4,5]
y1 = [2,4,6]

plt.plot(x1, y1, "r^")
plt.plot(x, y)

# %% [markdown]
# ^ -> carat

# %%
x = [1,2,3]
y = [2,4,6]

x1 = [3,4,5]
y1 = [2,4,6]

plt.plot(x1, y1, "rp")
plt.plot(x, y)

# %% [markdown]
# p -> pentagon

# %%
x = [1,2,3]
y = [2,4,6]

x1 = [3,4,5]
y1 = [2,4,6]

plt.plot(x1, y1, "r-.")
plt.plot(x, y)

# %%
# plot function x**3(x cube)
import numpy as np

x = np.array([1,2,3,4])
y = x**3
plt.plot(x,y)

# %%
# plot function x**3(x cube)
import numpy as np
# (start,end,increment)
x = np.arange(0,5,0.1)
y = x**3
plt.plot(x,y)

# %%
# plot function x**3(x cube)
import numpy as np
# (start,end,increment)
x = np.arange(0,5,0.1)
y = x**3
plt.plot(x,y, "ro")

# %%
a = [3,4,5]
plt.plot(a)
