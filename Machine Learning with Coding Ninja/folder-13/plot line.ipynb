# %%
import matplotlib.pyplot as plt

# %%
x = [0,1,2,3,4,5,6,7,9,10]
y = [1,2,5,10,17,26,37,50,82,101]
plt.plot(x, y)
plt.grid()
plt.show()
print(60,"to",70)
# Out:
# 60 to 70

# %%
a = [3,4,5]
plt.plot(a)
