# %%
import pandas as pd

# %%
iris = pd.read_csv('iris.csv')
iris
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
df = iris.copy()
df = df.values
df
for row in df:
    print(*row)
# Out:
# 5.1 3.5 1.4 0.2 Setosa
# 4.9 3.0 1.4 0.2 Setosa
# 4.7 3.2 1.3 0.2 Setosa
# 4.6 3.1 1.5 0.2 Setosa
# 5.0 3.6 1.4 0.2 Setosa
# 5.4 3.9 1.7 0.4 Setosa
# 4.6 3.4 1.4 0.3 Setosa
# 5.0 3.4 1.5 0.2 Setosa
# 4.4 2.9 1.4 0.2 Setosa
# 4.9 3.1 1.5 0.1 Setosa
# 5.4 3.7 1.5 0.2 Setosa
# 4.8 3.4 1.6 0.2 Setosa
# 4.8 3.0 1.4 0.1 Setosa
# 4.3 3.0 1.1 0.1 Setosa
# 5.8 4.0 1.2 0.2 Setosa
# 5.7 4.4 1.5 0.4 Setosa
# 5.4 3.9 1.3 0.4 Setosa
# 5.1 3.5 1.4 0.3 Setosa
# 5.7 3.8 1.7 0.3 Setosa
# 5.1 3.8 1.5 0.3 Setosa
# 5.4 3.4 1.7 0.2 Setosa
# 5.1 3.7 1.5 0.4 Setosa
# 4.6 3.6 1.0 0.2 Setosa
# 5.1 3.3 1.7 0.5 Setosa
# 4.8 3.4 1.9 0.2 Setosa
# 5.0 3.0 1.6 0.2 Setosa
# 5.0 3.4 1.6 0.4 Setosa
# 5.2 3.5 1.5 0.2 Setosa
# 5.2 3.4 1.4 0.2 Setosa
# 4.7 3.2 1.6 0.2 Setosa
# 4.8 3.1 1.6 0.2 Setosa
# 5.4 3.4 1.5 0.4 Setosa
# 5.2 4.1 1.5 0.1 Setosa
# 5.5 4.2 1.4 0.2 Setosa
# 4.9 3.1 1.5 0.2 Setosa
# 5.0 3.2 1.2 0.2 Setosa
# 5.5 3.5 1.3 0.2 Setosa
# 4.9 3.6 1.4 0.1 Setosa
# 4.4 3.0 1.3 0.2 Setosa
# 5.1 3.4 1.5 0.2 Setosa
# ...

# %%
import numpy as np
import csv

with open('iris.csv') as file_obj:
    data = csv.DictReader(file_obj, skipinitialspace=True)
    file_list = list(data)
    features = []
    for i in file_list:
        if file_list['variety']=='virginica' and file_list['petal-length']>1.5:
            features.append(i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 9
#       7 features = []
#       8 for i in file_list:
# ----> 9     if file_list['variety']=='virginica' and file_list['petal-length']>1.5:
#      10         features.append(i)
#
# TypeError: list indices must be integers or slices, not str

# %%
valid_data = df[(df['variety']=='virginica') & (df['petal.length']>1.5)]
valid_data
features = []
for i in range(len(df)):
    if df[(df['variety']=='virginica') & (df['petal.length']>1.5)]:
        features.append(i)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_35191/1057300990.py in ?()
#       1 valid_data = df[(df['variety']=='virginica') & (df['petal.length']>1.5)]
#       2 valid_data
#       3 features = []
#       4 for i in range(len(df)):
# ----> 5     if df[(df['variety']=='virginica') & (df['petal.length']>1.5)]:
#       6         features.append(i)
#
# ~/.local/lib/python3.10/site-packages/pandas/core/generic.py in ?(self)
#    1517     @final
#    1518     def __nonzero__(self) -> NoReturn:
# -> 1519         raise ValueError(
#    1520             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1521             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1522         )
#
# ValueError: The truth value of a DataFrame is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
import pandas as pd
columns = ['sl','sw','pl','pw','flower_type']
iris = pd.read_csv('iris.csv', names=columns)
print(len(iris))
iris = iris[iris.flower_type=='Iris-virginica']
print(len(iris))
iris = iris[iris.pl>1.5]
iris = iris.values
print("heloo")
for row in iris :
    print("hello")
    print(*row)
print("sbsfb")
# Out:
# 151
# 0
# heloo
# sbsfb

# %%
df.columns
# Out:
# Index(['sl', 'sw', 'pl', 'pw', 'flower_type'], dtype='object')

# %%
import pandas as pd
columns = ['sl','sw','pl','pw','flower_type']
iris = pd.read_csv('iris.csv', names=columns)
iris = iris[iris.flower_type=='Iris-virginica']
iris = iris[iris.pl>1.5]
iris = iris.values
for row in iris :
    print(*row)
